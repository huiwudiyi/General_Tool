# %%
import os
import pickle
import json
import pandas as pd

# %%
# Out:
# 只列出文件:
# ...

# %%
load_pickle('./5179.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 load_pickle('./5179.pkl')
#
# Cell In[6], line 10, in load_pickle(filepath)
#       8 def load_pickle(filepath):
#       9     with open(filepath, 'rb') as f:
# ---> 10         return pickle.load(f)
#
# ModuleNotFoundError: No module named 'state'
