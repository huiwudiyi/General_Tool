# %%
import pickle

# %%
try:
    with open('../recall_outputs_backup/summary/61277.pkl', 'rb') as file:
        data = pickle.load(file)
        print("文件读取成功:", data)
except FileNotFoundError:
    print("错误：文件未找到，请检查文件路径是否正确。")
except pickle.UnpicklingError:
    print("错误：文件内容无法反序列化，请检查文件格式或是否已损坏。")
except Exception as e:
    print(f"发生其他未知错误：{e}")
# Out:
# 文件读取成功: {'title': '多天天气新（历史+未来）', 'original_description': '工具描述:该卡片为多天天气的预报详情卡，将目标地区的多天天气，在日历表中展现，支持切换城市、月份查看整月逐日气象，提供日历 / 列表两种展示模式，直观展示每日天气图标、当日高低温，满足月度出行、穿搭规划需求。 工具返回内容:目标城市、查询年月、日历视图每日日期、当日天气图标、当日最低 / 最高气温、高亮标记当日日期 插件满足样式 （1）顶部配置城市下拉框、月份下拉框，右侧提供「日历 / 列表」视图切换标签； （2）采用标准日历排版，按周一至周日排布日期，每日单元集成天气图标、高低温数值； （3）当前日期使用蓝色边框高亮区分，直观定位今日天气； （4）底部设置「展开」下拉按钮与「更多天气趋势」跳转按钮，功能分区清晰； 插件交互样式 （1）点击左上角城市下拉框，切换不同城市月度气象数据； （2）点击年月下拉框，切换其他月份完整天气预报； （3）点击右上角「日历 / 列表」标签，切换两种预报展示形式； （4）点击「展开」下拉按钮，加载更多日期气象信息； （5）点击「更多天气趋势」，跳转查看长期气象趋势详情页面。', 'resource_id': '61277', 'current_description': '工具描述:该卡片为多天天气的预报详情卡，将目标地区的多天天气，在日历表中展现，支持切换城市、月份查看整月逐日气象，提供日历 / 列表两种展示模式，直观展示每日天气图标、当日高低温，满足月度出行、穿搭规划需求。 工具返回内容:目标城市、查询年月、日历视图每日日期、当日天气图标、当日最低 / 最高气温、高亮标记当日日期 插件满足样式 （1）顶部配置城市下拉框、月份下拉框，右侧提供「日历 / 列表」视图切换标签； （2）采用标准日历排版，按周一至周日排布日期，每日单元集成天气图标、高低温数值； （3）当前日期使用蓝色边框高亮区分，直观定位今日天气； （4）底部设置「展开」下拉按钮与「更多天气趋势」跳转按钮，功能分区清晰； 插件交互样式 （1）点击左上角城市下拉框，切换不同城市月度气象数据； （2）点击年月下拉框，切换其他月份完整天气预报； （3）点击右上角「日历 / 列表」标签，切换两种预报展示形式； （4）点击「展开」下拉按钮，加载更多日期气象信息；
# ...

# %%
len("工具描述：该卡用于承接搜索场景下文档类相关需求 工具返回内容：百度文库站内相关文档优质资源 插件满足样式（用户看到组件后，获取信息的核心内容）： （1）卡片顶部title为【检索Query+百度文库】，标识品牌来源 （2）默认展示一批站内优质文档资源，包含分类、标题、摘要、内容页数信息、阅读次数、标签信息 插件交互样式（用户无法直接获取内容，但可以通过点击组件来获取其他内容）： （1）用户通过点击卡片内容进入对应的资源落地页查看资源详情 （2）点击 查看更多 ，可跳转至文库对应资源站搜结果页")
# Out:
# 248

# %%
data
# Out:
# {'title': '多天天气新（历史+未来）',
#  'original_description': '工具描述:该卡片为多天天气的预报详情卡，将目标地区的多天天气，在日历表中展现，支持切换城市、月份查看整月逐日气象，提供日历 / 列表两种展示模式，直观展示每日天气图标、当日高低温，满足月度出行、穿搭规划需求。 工具返回内容:目标城市、查询年月、日历视图每日日期、当日天气图标、当日最低 / 最高气温、高亮标记当日日期 插件满足样式 （1）顶部配置城市下拉框、月份下拉框，右侧提供「日历 / 列表」视图切换标签； （2）采用标准日历排版，按周一至周日排布日期，每日单元集成天气图标、高低温数值； （3）当前日期使用蓝色边框高亮区分，直观定位今日天气； （4）底部设置「展开」下拉按钮与「更多天气趋势」跳转按钮，功能分区清晰； 插件交互样式 （1）点击左上角城市下拉框，切换不同城市月度气象数据； （2）点击年月下拉框，切换其他月份完整天气预报； （3）点击右上角「日历 / 列表」标签，切换两种预报展示形式； （4）点击「展开」下拉按钮，加载更多日期气象信息； （5）点击「更多天气趋势」，跳转查看长期气象趋势详情页面。',
#  'resource_id': '61277',
# ...

# %%
try:
    with open('../recall_outputs_backup/summary/50159.pkl', 'rb') as file:
        datas = pickle.load(file)
        print("文件读取成功:", datas)
except FileNotFoundError:
    print("错误：文件未找到，请检查文件路径是否正确。")
except pickle.UnpicklingError:
    print("错误：文件内容无法反序列化，请检查文件格式或是否已损坏。")
except Exception as e:
    print(f"发生其他未知错误：{e}")
# Out:
# 文件读取成功: {'title': '5428股票专项AE', 'original_description': '工具描述：该工具集合用于提供新三板个股实时行情数据查询。 工具返回内容：新三板个股现价、收盘状态、基础交易指标、价格走势图表。 插件满足样式：（用户看到组件后，获取信息的核心内容） （1）个股实时单价、涨跌金额、涨跌幅，股票代码与名称、收盘时间 （2）当日核心交易数据：今开、昨收、最高价、最低价、成交量、成交额、总市值、市盈率、换手率 （3）个股当日分时价格走势图表，标注当日价格区间与交易时段 插件交互样式：（用户无法直接获取内容，但可以通过点击组件来获取其他内容） （1）顶部可切换「新三板」「港股」板块标签，查看不同市场标的 （2）行情栏可切换「简况」「财务」「分析」标签，查看个股基础资料、财务报表、行情分析内容 （3）走势图表可切换分时、五日、日 K、周 K、月 K 及更多周期走势 （4）底部按钮可点击「股票开户」跳转开户页面、点击「添加自选」将个股加入自选列表', 'resource_id': '50159', 'current_description': '工具描述：该工具集合用于提供新三板个股实时行情数据查询。 工具返回内容：新三板个股现价、收盘状态、基础交易指标、价格走势图表。 插件满足样式：（用户看到组件后，获取信息的核心内容） （1）个股实时单价、涨跌金额、涨跌幅，股票代码与名称、收盘时间 （2）当日核心交易数据：今开、昨收、最高价、最低价、成交量、成交额、总市值、市盈率、换手率 （3）个股当日分时价格走势图表，标注当日价格区间与交易时段 插件交互样式：（用户无法直接获取内容，但可以通过点击组件来获取其他内容） （1）顶部可切换「新三板」「港股」板块标签，查看不同市场标的 （2）行情栏可切换「简况」「财务」「分析」标签，查看个股基础资料、财务报表、行情分析内容 （3）走势图表可切换分时、五日、日 K、周 K、月 K 及更多周期走势 （4）底部按钮可点击「股票开户」跳转开户页面、点击「添加自选」将个股加入自选列表', 'current_version_id': 4, 'next_version_id': 5, 'best_description': '工具描述：该工具集合用于提供新三板个股实时行情数据查询。 工具返回内容：新三板个股现价
# ...

# %%
datas
# Out:
# {'title': '5428股票专项AE',
#  'original_description': '工具描述：该工具集合用于提供新三板个股实时行情数据查询。 工具返回内容：新三板个股现价、收盘状态、基础交易指标、价格走势图表。 插件满足样式：（用户看到组件后，获取信息的核心内容） （1）个股实时单价、涨跌金额、涨跌幅，股票代码与名称、收盘时间 （2）当日核心交易数据：今开、昨收、最高价、最低价、成交量、成交额、总市值、市盈率、换手率 （3）个股当日分时价格走势图表，标注当日价格区间与交易时段 插件交互样式：（用户无法直接获取内容，但可以通过点击组件来获取其他内容） （1）顶部可切换「新三板」「港股」板块标签，查看不同市场标的 （2）行情栏可切换「简况」「财务」「分析」标签，查看个股基础资料、财务报表、行情分析内容 （3）走势图表可切换分时、五日、日 K、周 K、月 K 及更多周期走势 （4）底部按钮可点击「股票开户」跳转开户页面、点击「添加自选」将个股加入自选列表',
#  'resource_id': '50159',
#  'current_description': '工具描述：该工具集合用于提供新三板个股实时行情数据查询。 工具返回内容：新三板个股现价、收盘状态、基础交易指标、价格走势图表。 插件满足样式：（用户看到组件后，获取信息的核心内容） （1）个股实时单价、涨跌金额、涨跌幅，股票代码与名称、收盘时间 （2）当日核心交易数据：今开、昨收、最高价、最低价、成交量、成交额、总市值、市盈率、换手率 （3）个股当日分时价格走势图表，标注当日价格区间与交易时段 插件交互样式：（用户无法直接获取内容，但可以通过点击组件来获取其他内容） （1）顶部可切换「新三板」「港股」板块标签，查看不同市场标的 （2）行情栏可切换「简况」「财务」「分析」标签，查看个股基础资料、财务报表、行情分析内容 （3）走势图表可切换分时、五日、日 K、周 K、月 K 及更多周期走势 （4）底部按钮可点击「股票开户」跳转开户页面、点击「添加自选」将个股加入自选列表',
#  'current_version_id': 4,
#  'next_version_id': 5,
# ...
