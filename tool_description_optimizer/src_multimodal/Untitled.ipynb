# %%
import pandas as pd
import pickle

# %%
with open("../data/data_multimodal/multimodal_output/checkpoints/8756.ckpt", 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'node': 'describe:failed',
#  'state': {'srcid': '8756',
#   'queries': ['中国农业银行六安木厂支行电话'],
#   'label_data': '[query] 中国农业银行六安木厂支行电话\n[召回数据] 标题: 中国农业银行客服电话\n类型: 企业官方号码\n认证: 未经安全审核\n主号码: 95599,4006695599,4006195599\n\n电话列表:\n  信用卡客服热线: 400-669-5599\n  白金贵宾服务专线: 400-619-5599\n  客服热线: 95599\n  境外客服热线: 021-61695599\n  信用卡客户服务热线（境外）: 021-61195599\n  白金贵宾服务专线（境外）: 021-61295599',
#   'screenshots': ['../data/data_multimodal/multimodal_output/embedded_images/row3_1.png'],
#   'description': '',
#   'layout_text': '',
#   'function_text': '',
#   'judge_score': None,
#   'judge_passed': False,
#   'evidence': [],
#   'suggestions': [],
#   'round_id': 0,
#   'max_rounds': 2,
#   'min_pass_score': 3,
#   'final_description': '',
#   'accepted': False,
#   'description_history': [],
#   'judge_history': [],
#   'generator_history': []}}
